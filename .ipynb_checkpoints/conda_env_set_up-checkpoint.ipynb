# %%
# %%writefile ~/ML_course_assessment/setup.sh
# tee ~/ML_course_assessment/ML_course_assessment.yml << END
# name: ML_course_assessment
# channels:
#   - conda-forge
# dependencies:
#   - python==3.9
#   - numpy
#   - pandas
#   - scipy
#   - statsmodels
#   - pingouin
#   - scikit-learn
#   - matplotlib
#   - seaborn
#   - plotly
#   - pip
#   - ipykernel
#   - nb_conda_kernels
#   - pip:
#     - nibabel
#     - nipype
#     - nilearn
#     - joblib
#
# prefix: /home/jovyan/envs/ML_course_assessment
#
# END
#
# conda env update --file ~/ML_course_assessment/ML_course_assessment.yml
# conda activate ML_course_assessment
# # python -m ipykernel update --user --name ML_course_assessment --display-name "Python (ML_course_assessment)"
# Out:
# Overwriting /home/jovyan/ML_course_assessment/setup.sh

# %%
# !source ~/ML_course_assessment/setup.sh
# Out:
# name: ML_course_assessment
# channels:
#   - conda-forge
# dependencies:
#   - python==3.9
#   - numpy
#   - pandas
#   - scipy
#   - statsmodels
#   - pingouin
#   - scikit-learn
#   - matplotlib
#   - seaborn
#   - plotly
#   - pip
#   - ipykernel
#   - nb_conda_kernels
#   - pip:
#     - nibabel
#     - nipype
#     - nilearn
#     - joblib
#
# prefix: /home/jovyan/envs/ML_course_assessment
#
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.0
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# Downloading and Extracting Packages
# plotly-5.3.1         | 6.8 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Installing pip dependencies: \ Ran pip subprocess with arguments:
# ['/home/jovyan/env/ML_course_assessment/bin/python', '-m', 'pip', 'install', '-U', '-r', '/home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt']
# Pip subprocess output:
# Requirement already satisfied: nibabel in /home/jovyan/.local/lib/python3.9/site-packages (from -r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: nipype in /home/jovyan/.local/lib/python3.9/site-packages (from -r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (1.6.0)
# Collecting nipype
#   Downloading nipype-1.6.1-py3-none-any.whl (3.2 MB)
# Collecting nilearn
#   Downloading nilearn-0.8.0-py3-none-any.whl (4.9 MB)
# Requirement already satisfied: joblib in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from -r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: packaging>=14.3 in /home/jovyan/.local/lib/python3.9/site-packages (from nibabel->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 1)) (20.9)
# Requirement already satisfied: numpy>=1.14 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from nibabel->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 1)) (1.21.2)
# Requirement already satisfied: prov>=1.5.2 in /home/jovyan/.local/lib/python3.9/site-packages (from nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: rdflib>=5.0.0 in /home/jovyan/.local/lib/python3.9/site-packages (from nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (5.0.0)
# Requirement already satisfied: click>=6.6.0 in /home/jovyan/.local/lib/python3.9/site-packages (from nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (8.0.1)
# Requirement already satisfied: pydot>=1.2.3 in /home/jovyan/.local/lib/python3.9/site-packages (from nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: simplejson>=3.8.0 in /home/jovyan/.local/lib/python3.9/site-packages (from nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (3.17.2)
# Requirement already satisfied: python-dateutil>=2.2 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: scipy>=0.14 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (1.7.1)
# Requirement already satisfied: traits!=5.0,>=4.6 in /home/jovyan/.local/lib/python3.9/site-packages (from nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (6.2.0)
# Requirement already satisfied: networkx>=2.0 in /home/jovyan/.local/lib/python3.9/site-packages (from nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (2.5.1)
# Requirement already satisfied: etelemetry>=0.2.0 in /home/jovyan/.local/lib/python3.9/site-packages (from nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: filelock>=3.0.0 in /home/jovyan/.local/lib/python3.9/site-packages (from nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (3.0.12)
# Requirement already satisfied: scikit-learn>=0.21 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from nilearn->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 3)) (0.24.2)
# Requirement already satisfied: requests>=2 in /home/jovyan/.local/lib/python3.9/site-packages (from nilearn->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 3)) (2.25.1)
# Requirement already satisfied: pandas>=0.24.0 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from nilearn->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: ci-info>=0.2 in /home/jovyan/.local/lib/python3.9/site-packages (from etelemetry>=0.2.0->nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: decorator<5,>=4.3 in /home/jovyan/.local/lib/python3.9/site-packages (from networkx>=2.0->nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (4.4.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from packaging>=14.3->nibabel->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from pandas>=0.24.0->nilearn->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 3)) (2021.1)
# Requirement already satisfied: lxml>=3.3.5 in /home/jovyan/.local/lib/python3.9/site-packages (from prov>=1.5.2->nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (4.6.3)
# Requirement already satisfied: six>=1.5 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from python-dateutil>=2.2->nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: isodate in /home/jovyan/.local/lib/python3.9/site-packages (from rdflib>=5.0.0->nipype->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/jovyan/.local/lib/python3.9/site-packages (from requests>=2->nilearn->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from requests>=2->nilearn->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 3)) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /home/jovyan/.local/lib/python3.9/site-packages (from requests>=2->nilearn->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 3)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jovyan/.local/lib/python3.9/site-packages (from requests>=2->nilearn->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 3)) (1.26.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from scikit-learn>=0.21->nilearn->-r /home/jovyan/ML_course_assessment/condaenv.pfhgfwf6.requirements.txt (line 3)) (2.2.0)
# Installing collected packages: nipype, nilearn
#   Attempting uninstall: nipype
#     Found existing installation: nipype 1.6.0
#     Uninstalling nipype-1.6.0:
#       Successfully uninstalled nipype-1.6.0
# Successfully installed nilearn-0.8.0 nipype-1.6.1
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate ML_course_assessment
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
# usage: __main__.py [-h] [--debug] [--quiet] [--init] [--no-stdout]
#                    [--no-stderr] [--trio-loop] [--autoindent]
#                    [--no-autoindent] [--automagic] [--no-automagic] [--pdb]
#                    [--no-pdb] [--pprint] [--no-pprint] [--color-info]
#                    [--no-color-info] [--ignore-cwd] [--no-ignore-cwd]
#                    [--nosep] [--secure] [--no-secure]
#                    [--profile-dir ProfileDir.location]
#                    [--profile IPKernelApp.profile]
#                    [--ipython-dir IPKernelApp.ipython_dir]
#                    [--log-level IPKernelApp.log_level]
#                    [--config IPKernelApp.extra_config_file]
#                    [--ip IPKernelApp.ip] [--hb IPKernelApp.hb_port]
#                    [--shell IPKernelApp.shell_port]
#                    [--iopub IPKernelApp.iopub_port]
#                    [--stdin IPKernelApp.stdin_port]
#                    [--control IPKernelApp.control_port]
#                    [-f IPKernelApp.connection_file]
#                    [--transport IPKernelApp.transport]
#                    [--autocall ZMQInteractiveShell.autocall]
#                    [--colors ZMQInteractiveShell.colors]
#                    [--logfile ZMQInteractiveShell.logfile]
#                    [--logappend ZMQInteractiveShell.logappend]
#                    [-c IPKernelApp.code_to_run] [-m IPKernelApp.module_to_run]
#                    [--ext IPKernelApp.extra_extensions]
#                    [--gui IPKernelApp.gui] [--pylab [IPKernelApp.pylab]]
#                    [--matplotlib [IPKernelApp.matplotlib]]
#                    [--cache-size ZMQInteractiveShell.cache_size]
#                    [--ident Session.session] [--user Session.username]
#                    [--keyfile Session.keyfile]
#                    [extra_args [extra_args ...]]
# __main__.py: error: argument --Session.username: expected one argument

# %%
conda env update -f ML_course_assessment.yml
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.0
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# Downloading and Extracting Packages
# ipykernel-6.3.1      | 173 KB    | ##################################### | 100%
# defusedxml-0.7.1     | 23 KB     | ##################################### | 100%
# plotly-5.3.0         | 6.8 MB    | ##################################### | 100%
# markupsafe-2.0.1     | 22 KB     | ##################################### | 100%
# pip-21.2.4           | 1.1 MB    | ##################################### | 100%
# scikit-learn-0.24.2  | 7.6 MB    | ##################################### | 100%
# entrypoints-0.3      | 8 KB      | ##################################### | 100%
# numpy-1.21.2         | 6.2 MB    | ##################################### | 100%
# nbclient-0.5.4       | 60 KB     | ##################################### | 100%
# pandas-1.3.2         | 13.0 MB   | ##################################### | 100%
# pandocfilters-1.4.2  | 9 KB      | ##################################### | 100%
# pandoc-2.14.2        | 12.1 MB   | ##################################### | 100%
# pyrsistent-0.17.3    | 90 KB     | ##################################### | 100%
# importlib-metadata-4 | 32 KB     | ##################################### | 100%
# webencodings-0.5.1   | 12 KB     | ##################################### | 100%
# nbformat-5.1.3       | 47 KB     | ##################################### | 100%
# async_generator-1.10 | 18 KB     | ##################################### | 100%
# nest-asyncio-1.5.1   | 9 KB      | ##################################### | 100%
# jsonschema-3.2.0     | 45 KB     | ##################################### | 100%
# bleach-4.1.0         | 121 KB    | ##################################### | 100%
# scipy-1.7.1          | 22.0 MB   | ##################################### | 100%
# packaging-21.0       | 35 KB     | ##################################### | 100%
# nbconvert-6.1.0      | 547 KB    | ##################################### | 100%
# zipp-3.5.0           | 12 KB     | ##################################### | 100%
# pingouin-0.4.0       | 159 KB    | ##################################### | 100%
# jupyterlab_pygments- | 8 KB      | ##################################### | 100%
# openssl-1.1.1k       | 2.1 MB    | ##################################### | 100%
# mistune-0.8.4        | 54 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
