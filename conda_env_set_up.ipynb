# %%
# %%writefile ~/ML_course_assessment/setup.sh
# tee ~/ML_course_assessment/ML_course_assessment.yml << END
# name: ML_course_assessment
# channels:
#   - conda-forge
# dependencies:
#   - python==3.9
#   - numpy
#   - pandas
#   - scipy
#   - statsmodels
#   - pingouin
#   - scikit-learn
#   - matplotlib
#   - seaborn
#   - plotly
#   - pip
#   - ipykernel
#   - nb_conda_kernels
#   - pip:
#     - nibabel
#
# prefix: /home/jovyan/envs/ML_course_assessment
#
# END
#
# conda env create --file ~/ML_course_assessment/ML_course_assessment.yml
# conda activate ML_course_assessment
# python -m ipykernel install --user --name ML_course_assessment --display-name "Python (ML_course_assessment)"
# Out:
# Writing /home/jovyan/ML_course_assessment/setup.sh

# %%
# !source ~/ML_course_assessment/setup.sh
# Out:
# name: ML_course_assessment
# channels:
#   - conda-forge
# dependencies:
#   - python==3.9
#   - numpy
#   - pandas
#   - scipy
#   - statsmodels
#   - pingouin
#   - scikit-learn
#   - matplotlib
#   - seaborn
#   - plotly
#   - pip
#   - ipykernel
#   - nb_conda_kernels
#   - pip:
#     - nibabel
#
# prefix: /home/jovyan/envs/ML_course_assessment
#
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.0
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# Downloading and Extracting Packages
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
# libopenblas-0.3.17   | 9.2 MB    | ##################################### | 100%
# requests-2.26.0      | 52 KB     | ##################################### | 100%
# plotly-5.1.0         | 6.7 MB    | ##################################### | 100%
# xarray-0.19.0        | 614 KB    | ##################################### | 100%
# charset-normalizer-2 | 32 KB     | ##################################### | 100%
# libstdcxx-ng-11.1.0  | 4.2 MB    | ##################################### | 100%
# libblas-3.9.0        | 11 KB     | ##################################### | 100%
# ipython-7.26.0       | 1.1 MB    | ##################################### | 100%
# libgomp-11.1.0       | 427 KB    | ##################################### | 100%
# debugpy-1.4.1        | 2.0 MB    | ##################################### | 100%
# pip-21.2.2           | 1.1 MB    | ##################################### | 100%
# pillow-8.3.1         | 687 KB    | ##################################### | 100%
# numpy-1.21.1         | 6.2 MB    | ##################################### | 100%
# liblapack-3.9.0      | 11 KB     | ##################################### | 100%
# pandas-1.3.1         | 13.0 MB   | ##################################### | 100%
# threadpoolctl-2.2.0  | 16 KB     | ##################################### | 100%
# ld_impl_linux-64-2.3 | 667 KB    | ##################################### | 100%
# scipy-1.7.0          | 22.0 MB   | ##################################### | 100%
# outdated-0.2.1       | 10 KB     | ##################################### | 100%
# urllib3-1.26.6       | 99 KB     | ##################################### | 100%
# libgcc-ng-11.1.0     | 908 KB    | ##################################### | 100%
# libgfortran5-11.1.0  | 1.7 MB    | ##################################### | 100%
# python-dateutil-2.8. | 240 KB    | ##################################### | 100%
# cffi-1.14.6          | 227 KB    | ##################################### | 100%
# tzdata-2021a         | 121 KB    | ##################################### | 100%
# krb5-1.19.2          | 1.4 MB    | ##################################### | 100%
# tenacity-8.0.1       | 21 KB     | ##################################### | 100%
# pyzmq-22.2.0         | 520 KB    | ##################################### | 100%
# idna-3.1             | 52 KB     | ##################################### | 100%
# lz4-c-1.9.3          | 179 KB    | ##################################### | 100%
# ipykernel-6.0.3      | 170 KB    | ##################################### | 100%
# libgfortran-ng-11.1. | 19 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: | Enabling nb_conda_kernels...
# CONDA_PREFIX: /home/jovyan/env/ML_course_assessment
# Status: enabled
#
# done
# Installing pip dependencies: - Ran pip subprocess with arguments:
# ['/home/jovyan/env/ML_course_assessment/bin/python', '-m', 'pip', 'install', '-U', '-r', '/home/jovyan/ML_course_assessment/condaenv.vcwi34kj.requirements.txt']
# Pip subprocess output:
# Requirement already satisfied: nibabel in /home/jovyan/.local/lib/python3.9/site-packages (from -r /home/jovyan/ML_course_assessment/condaenv.vcwi34kj.requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: numpy>=1.14 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from nibabel->-r /home/jovyan/ML_course_assessment/condaenv.vcwi34kj.requirements.txt (line 1)) (1.21.1)
# Requirement already satisfied: packaging>=14.3 in /home/jovyan/.local/lib/python3.9/site-packages (from nibabel->-r /home/jovyan/ML_course_assessment/condaenv.vcwi34kj.requirements.txt (line 1)) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/jovyan/env/ML_course_assessment/lib/python3.9/site-packages (from packaging>=14.3->nibabel->-r /home/jovyan/ML_course_assessment/condaenv.vcwi34kj.requirements.txt (line 1)) (2.4.7)
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate ML_course_assessment
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
# Installed kernelspec ML_course_assessment in /home/jovyan/.local/share/jupyter/kernels/ml_course_assessment
